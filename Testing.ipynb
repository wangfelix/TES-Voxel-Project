# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import math
import random
import torch
# import opencv
from env_carla import Environment

# %%
env = Environment()

# %%
env.init_ego()
obs = env.reset()

# %%
obs = env.reset()[0]

# %%
obs[1][0]
# Out:
# 0.0

# %%
obs = env.step(random.randrange(0,9))[0]
# obs = torch.reshape(obs, (360,480,3))
print(obs.shape)
plt.imshow(obs)
# Out:
# (480, 3)

# %%
obs = env.get_observation()

# %%
k = np.array([1,2])

# %%
k.dtype
# Out:
# dtype('int64')
